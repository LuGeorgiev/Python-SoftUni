# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use("dark_background")

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %% [markdown]
# # Data visualizatio

# %%
flags_data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data", header=None)
flags_data.columns = ["name", "landmass", "zone", "area", "population", "language","religion", "bars",
                     "stripes", "colours", "red", "green", "blue", "gold", "white", "black", "orange", "mainhue", 
                      "circles", "crosses", "saltires", "quarters", "sunstars", "crescent", "triangle", "icon",
                      "animate", "text", "topleft", "botright" ]
flags_data
# Out:
#                name  landmass  zone  area  population  language  religion  \
# 0       Afghanistan         5     1   648          16        10         2
# 1           Albania         3     1    29           3         6         6
# 2           Algeria         4     1  2388          20         8         2
# 3    American-Samoa         6     3     0           0         1         1
# 4           Andorra         3     1     0           0         6         0
# ..              ...       ...   ...   ...         ...       ...       ...
# 189   Western-Samoa         6     3     3           0         1         1
# 190      Yugoslavia         3     1   256          22         6         6
# 191           Zaire         4     2   905          28        10         5
# 192          Zambia         4     2   753           6        10         5
# 193        Zimbabwe         4     2   391           8        10         5
#
#      bars  stripes  colours  ...  saltires  quarters  sunstars  crescent  \
# ...

# %%
flags_data.describe().T
# Out:
#             count        mean          std  min  25%    50%     75%      max
# landmass    194.0    3.572165     1.553018  1.0  3.0    4.0    5.00      6.0
# zone        194.0    2.211340     1.308274  1.0  1.0    2.0    4.00      4.0
# area        194.0  700.046392  2170.927932  0.0  9.0  111.0  471.25  22402.0
# population  194.0   23.268041    91.934085  0.0  0.0    4.0   14.00   1008.0
# language    194.0    5.340206     3.496517  1.0  2.0    6.0    9.00     10.0
# religion    194.0    2.190722     2.061167  0.0  1.0    1.0    4.00      7.0
# bars        194.0    0.453608     1.038339  0.0  0.0    0.0    0.00      5.0
# stripes     194.0    1.551546     2.328005  0.0  0.0    0.0    3.00     14.0
# colours     194.0    3.463918     1.300154  1.0  3.0    3.0    4.00      8.0
# red         194.0    0.788660     0.409315  0.0  1.0    1.0    1.00      1.0
# green       194.0    0.469072     0.500334  0.0  0.0    0.0    1.00      1.0
# ...

# %%
with open("data/flag.names", "r") as file:
    content = file.read()

# %%
print(content)
# Out:
# 1. TItle: Flag database
#
# 2. Source Information
#    -- Creators: Collected primarily from the "Collins Gem Guide to Flags":
#       Collins Publishers (1986).
#    -- Donor: Richard S. Forsyth
#              8 Grosvenor Avenue
#              Mapperley Park
#              Nottingham NG3 5DX
#              0602-621676
#    -- Date: 5/15/1990
#
# 3. Past Usage:
#    -- None known other than what is shown in Forsyth's PC/BEAGLE User's Guide.
#
# 4. Relevant Information:
#    -- This data file contains details of various nations and their flags.
#       In this file the fields are separated by spaces (not commas).  With
#       this data you can try things like predicting the religion of a country
#       from its size and the colours in its flag.
#    -- 10 attributes are numeric-valued.  The remainder are either Boolean-
#       or nominal-valued.
#
# 5. Number of Instances: 194
#
# 6. Number of attributes: 30 (overall)
#
# 7. Attribute Information:
# ...

# %%
flags_data.columns
# Out:
# Index(['name', 'landmass', 'zone', 'area', 'population', 'language',
#        'religion', 'bars', 'stripes', 'colours', 'red', 'green', 'blue',
#        'gold', 'white', 'black', 'orange', 'mainhue', 'circles', 'crosses',
#        'saltires', 'quarters', 'sunstars', 'crescent', 'triangle', 'icon',
#        'animate', 'text', 'topleft', 'botright'],
#       dtype='object')

# %%
plt.hist(np.log10(flags_data.area[flags_data.area > 0]), bins=20)
plt.title("Distribution of country areas")
plt.xlabel("$\lg\ {Area}$")
plt.ylabel("Number of countries")

plt.show()

# %%
flags_data[flags_data.area > 8000]
# Out:
#        name  landmass  zone   area  population  language  religion  bars  \
# 23   Brazil         2     3   8512         119         6         0     0
# 31   Canada         1     4   9976          24         1         1     2
# 37    China         5     1   9561        1008         7         6     0
# 183     USA         1     4   9363         231         1         1     0
# 184    USSR         5     1  22402         274         5         6     0
#
#      stripes  colours  ...  saltires  quarters  sunstars  crescent  triangle  \
# 23         0        4  ...         0         0        22         0         0
# 31         0        2  ...         0         0         0         0         0
# 37         0        2  ...         0         0         5         0         0
# 183       13        3  ...         0         1        50         0         0
# 184        0        2  ...         0         0         1         0         0
#
#      icon  animate text  topleft  botright
# ...

# %%
plt.boxplot(np.log10(flags_data.area[flags_data.area > 0]))
plt.xticks([1], ["Area"])
plt.show()

# %%
land_masses =[]
mean_areads =[]

for landmass, group_data in flags_data.groupby("landmass"):
    #print(landmass, group_data)
    print(landmass,"=>", group_data.area.mean())    
    land_masses.append(landmass)
    mean_areads.append(group_data.area.mean())
# Out:
# 1 => 779.4516129032259
# 2 => 1211.1176470588234
# 3 => 139.5142857142857
# 4 => 534.3076923076923
# 5 => 1222.8974358974358
# 6 => 534.85

# %%
plt.bar(land_masses, mean_areads)
plt.title("Mean area by continent")
plt.xlabel("continet")
plt.xlabel("mean area")
plt.show()

# %%
pd.pivot_table(flags_data,columns=["red", "green"])
# Out:
#           red  green
# landmass  0    0        2.913043
#                1        3.777778
#           1    0        3.712500
#                1        3.575342
# zone      0    0        2.391304
#                           ...
# animate   1    1        0.342466
# text      0    0        0.000000
#                1        0.166667
#           1    0        0.025000
#                1        0.150685
# Length: 96, dtype: float64

# %%
plt.figure(figsize = (10,8))

plt.scatter(flags_data.area, flags_data.population, marker = "x", c="r", s= 200)
plt.title("Popultaio vs. area")
plt.xlabel("Area [thousands sq km]")
plt.ylabel("Population im millions")
plt.show()

# %%
plt.scatter(np.log10(flags_data.area), np.log10( flags_data.population))
plt.title("Popultaio vs. area")
plt.xlabel("lg Area [thousands sq km]")
plt.ylabel("lg Population im millions")
plt.show()
# Out:
# C:\Users\LyubomirGeorgiev\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
pie = [10,15,56]
plt.pie(pie)
plt.show()

# %% [markdown]
# ## Seaborn - library for visualization or Plotly

# %%
powerplant_data = pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/boot/nuclear.csv")
powerplant_data
# Out:
#     Unnamed: 0    cost   date  t1  t2   cap  pr  ne  ct  bw  cum.n  pt
# 0            1  460.05  68.58  14  46   687   0   1   0   0     14   0
# 1            2  452.99  67.33  10  73  1065   0   0   1   0      1   0
# 2            3  443.22  67.33  10  85  1065   1   0   1   0      1   0
# 3            4  652.32  68.00  11  67  1065   0   1   1   0     12   0
# 4            5  642.23  68.00  11  78  1065   1   1   1   0     12   0
# 5            6  345.39  67.92  13  51   514   0   1   1   0      3   0
# 6            7  272.37  68.17  12  50   822   0   0   0   0      5   0
# 7            8  317.21  68.42  14  59   457   0   0   0   0      1   0
# 8            9  457.12  68.42  15  55   822   1   0   0   0      5   0
# 9           10  690.19  68.33  12  71   792   0   1   1   1      2   0
# 10          11  350.63  68.58  12  64   560   0   0   0   0      3   0
# 11          12  402.59  68.75  13  47   790   0   1   0   0      6   0
# ...

# %%
powerplant_data[powerplant_data["pr"] == 1]["cap"].max()
# Out:
# 1065
